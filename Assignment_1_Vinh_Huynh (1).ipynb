# %% [markdown]
# # Assignment 1

# %% [markdown]
# **Data sets to use: avocado.csv**

# %% [markdown]
# * Possible points: 100
#
# * Rename the .ipynb notebook as Assignment_1_{FirstName}_{LastName}.ipynb before submitting your notebook. Eg. Assignment_1_Vijay_Koju.ipynb
#
# * Due Date: 03/03/2023 11:59pm
#
# * Submit the .ipynb notebook only. There is no need to submit the data file and any other write up. All your code, and answers should be included in the notebook.

# %% [markdown]
# ##### Include the following information:

# %% [markdown]
# * Name: Vinh Huynh
# * UTD ID: vxh210013
# * Email: vxh210013@utdallas.edu

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
#  1) Read the data from the CSV file into a DataFrame. (point: 1)

# %%
avocado=pd.read_csv("C:/Users/tuanv/Downloads/avocado.csv")

# %% [markdown]
# #### 2) Display type, memory consumption, and null count information using the info() method. (point: 1)

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# #### 3) Display the number of unique values in each column. (point: 1)

# %%
avocado.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# #### 4) Display the first and last five rows of data and the first and last four columns of data.  (point: 1)

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
avocado.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
avocado.iloc[:,:4]
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume
# 0               0  2015-12-27          1.33      64236.62
# 1               1  2015-12-20          1.35      54876.98
# 2               2  2015-12-13          0.93     118220.22
# 3               3  2015-12-06          1.08      78992.15
# 4               4  2015-11-29          1.28      51039.60
# ...           ...         ...           ...           ...
# 18244           7  2018-02-04          1.63      17074.83
# 18245           8  2018-01-28          1.71      13888.04
# 18246           9  2018-01-21          1.87      13766.76
# 18247          10  2018-01-14          1.93      16205.22
# 18248          11  2018-01-07          1.62      17489.58
#
# [18249 rows x 4 columns]

# %%
avocado.iloc[:,-4:]
# Out:
#        XLarge Bags          type  year            region
# 0              0.0  conventional  2015            Albany
# 1              0.0  conventional  2015            Albany
# 2              0.0  conventional  2015            Albany
# 3              0.0  conventional  2015            Albany
# 4              0.0  conventional  2015            Albany
# ...            ...           ...   ...               ...
# 18244          0.0       organic  2018  WestTexNewMexico
# 18245          0.0       organic  2018  WestTexNewMexico
# 18246          0.0       organic  2018  WestTexNewMexico
# 18247          0.0       organic  2018  WestTexNewMexico
# 18248          0.0       organic  2018  WestTexNewMexico
#
# [18249 rows x 4 columns]

# %% [markdown]
# #### 5) Get the general statistics of all the numerical columns. (point: 1)

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# #### 6) Multiply the Total Volume and AveragePrice columns, and store the result in a new column called EstimatedRevenue. Then, display the first five rows of this data to confirm that the column was added and has the correct values.  (point: 2)

# %%
avocado['EstimatedRevenue'] = avocado['AveragePrice']*avocado['Total Volume']

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  EstimatedRevenue
# 0  2015  Albany        85434.7046
# ...

# %% [markdown]
# #### 7) Create a DataFrame that’s grouped by region and type and that includes the average price for the grouped columns. Then, reset the index and display the first five rows.  (point: 3)

# %%
group7 = avocado.groupby(['region','type'])['AveragePrice'].mean().reset_index()
group7.head()
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %% [markdown]
# #### 8) Create a bar plot that shows the mean, median, and standard deviation of the Total Volume column by year.  (point: 5)

# %%
avocado_dt.groupby('year')['Total Volume'].agg(['mean','median','std']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### 9 How many unique regions are there?  (point: 1)

# %%
avocado['region'].nunique()
# Out:
# 54

# %% [markdown]
# #### 10) What is the average price for each type of avocado (organic and conventional)? Be sure to include just the type and AveragePrice columns in the results. (point: 2)

# %%
avocado.groupby('type')['AveragePrice'].mean()
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %% [markdown]
# #### 11) Which region has the lowest average price for organic avocados? (point: 5)

# %%
oavo = avocado[avocado['type'] == 'organic'].groupby('region')['AveragePrice'].mean()
oavo
# Out:
# region
# Albany                 1.773314
# Atlanta                1.607101
# BaltimoreWashington    1.724260
# Boise                  1.620237
# Boston                 1.757396
# BuffaloRochester       1.651361
# California             1.685207
# Charlotte              1.936982
# Chicago                1.744201
# CincinnatiDayton       1.402899
# Columbus               1.439290
# DallasFtWorth          1.324734
# Denver                 1.363195
# Detroit                1.428225
# GrandRapids            1.684970
# GreatLakes             1.495207
# HarrisburgScranton     1.767751
# HartfordSpringfield    2.229231
# Houston                1.270769
# Indianapolis           1.483136
# Jacksonville           1.828284
# LasVegas               1.748876
# LosAngeles             1.455562
# Louisville             1.468047
# MiamiFtLauderdale      1.602663
# Midsouth               1.602367
# Nashville              1.411302
# NewOrleansMobile       1.524320
# NewYork                2.053018
# ...

# %% [markdown]
# #### 12) Have the Total Bags sold per year of each type of avocado become more or less consistent over time? (point: 2)

# %%
avocado.groupby(['type', avocado['Date'].str[:4]])['Total Bags'].std()
# Out:
# type          Date
# conventional  2015    7.518535e+05
#               2016    1.405738e+06
#               2017    1.549660e+06
#               2018    2.033493e+06
# organic       2015    2.589149e+04
#               2016    6.756273e+04
#               2017    1.058683e+05
#               2018    1.407772e+05
# Name: Total Bags, dtype: float64

# %%
###13)Drop rows that have a region of TotalUS, and then check to see how many rows were dropped

# %%
dropr = avocado[avocado['region']=='TotalUS'].index
avocado.drop(dropr, inplace=True)
len(dropr)
# Out:
# 338

# %% [markdown]
# #### 14) Drop the Unnamed: 0, 4046, 4225, and 4770 columns. (point: 2)

# %%
avocado.drop(columns=['Unnamed: 0','4046','4225','4770'])
# Out:
#              Date  AveragePrice  Total Volume  Total Bags  Small Bags  \
# 0      2015-12-27          1.33      64236.62     8696.87     8603.62
# 1      2015-12-20          1.35      54876.98     9505.56     9408.07
# 2      2015-12-13          0.93     118220.22     8145.35     8042.21
# 3      2015-12-06          1.08      78992.15     5811.16     5677.40
# 4      2015-11-29          1.28      51039.60     6183.95     5986.26
# ...           ...           ...           ...         ...         ...
# 18244  2018-02-04          1.63      17074.83    13498.67    13066.82
# 18245  2018-01-28          1.71      13888.04     9264.84     8940.04
# 18246  2018-01-21          1.87      13766.76     9394.11     9351.80
# 18247  2018-01-14          1.93      16205.22    10969.54    10919.54
# 18248  2018-01-07          1.62      17489.58    12014.15    11988.14
#
#        Large Bags  XLarge Bags          type  year            region  \
# ...

# %% [markdown]
# #### 15) Notice that the column names are inconsistent. Use dictionary comprehension (similar to list comprehension, but for dictionaries) to create a dictionary where the keys are the column names with a space between the words and values as the column names without the space. Use this dictionary to rename the columns of the dataframe. (point: 10)

# %%
rename_avo = avocado_dt.rename(columns={'Total Volume':'TotalVolume','Total Bags':'TotalBags','Small Bags':'SmallBags','Large Bags':'LargeBags','XLarge Bags':'XLargeBags'})
rename_avo
# Out:
#        Unnamed: 0        Date  AveragePrice  TotalVolume     4046       4225  \
# 0               0  2015-12-27          1.33     64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35     54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93    118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08     78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28     51039.60   941.48   43838.39
# ...           ...         ...           ...          ...      ...        ...
# 18244           7  2018-02-04          1.63     17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71     13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87     13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93     16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62     17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# #### 16) Group, sum, and unstack this data to produce a DataFrame that looks like this: (point: 10)
#
# ![image.png](attachment:fdec889f-b284-40f0-87b1-d466557d7528.png)

# %%
Type = ['conventional', 'organic']
avo16 = rename_avo.loc[rename_avo['type'].isin(Type)]
avo166 = avo16.pivot_table(index=['region','year'], columns = 'type', values='TotalBags', aggfunc='sum')
avo166
# Out:
# type                   conventional     organic
# region           year
# Albany           2015     662366.17    57289.43
#                  2016     759091.14    79208.77
#                  2017     699561.17   135944.43
#                  2018     245240.75    41552.75
# Atlanta          2015    2935925.63    61065.24
# ...                             ...         ...
# West             2018   35978608.70  2074684.34
# WestTexNewMexico 2015    5399316.40   128763.94
#                  2016   10870856.07   403881.08
#                  2017   14195031.44   602152.24
#                  2018    3547372.46   149141.90
#
# [216 rows x 2 columns]

# %% [markdown]
# #### 17) Convert the Date column to the datetime type. Filter the data so it contains just the rows for 2015, for the conventional type, and for the region named Albany. Store just the Date, Total Bags, and Small Bags columns in a new DataFrame. (point: 10)

# %%
avocado['Date'] = pd.to_datetime(avocado['Date'])
data17 = avocado[(avocado['year']==2015) & (avocado['type']== 'conventional') & (avocado['region']== 'Albany')][['Date','Total Bags','Small Bags']]
data17
# Out:
#          Date  Total Bags  Small Bags
# 0  2015-12-27     8696.87     8603.62
# 1  2015-12-20     9505.56     9408.07
# 2  2015-12-13     8145.35     8042.21
# 3  2015-12-06     5811.16     5677.40
# 4  2015-11-29     6183.95     5986.26
# 5  2015-11-22     6683.91     6556.47
# 6  2015-11-15     8318.86     8196.81
# 7  2015-11-08     6829.22     6266.85
# 8  2015-11-01    11388.36    11104.53
# 9  2015-10-25     8625.92     8061.47
# 10 2015-10-18     8205.66     7877.86
# 11 2015-10-11    10123.90     9866.27
# 12 2015-10-04     8756.75     8379.98
# 13 2015-09-27     6034.46     5888.87
# 14 2015-09-20     9267.36     8489.10
# 15 2015-09-13     9286.68     8665.19
# 16 2015-09-06     7990.10     7762.87
# 17 2015-08-30    10306.73    10218.93
# 18 2015-08-23    10880.36    10745.79
# 19 2015-08-16    10443.22    10297.68
# 20 2015-08-09     9225.89     9116.34
# 21 2015-08-02    11847.02    11768.52
# 22 2015-07-26    13192.69    13061.53
# 23 2015-07-19    11287.48    11103.49
# ...

# %% [markdown]
# #### 18) Melt the data in the Total Bags and Small Bags columns, but not the values in the Date column. Name the column that contains the type of bag Bags, and name the column that contains the number of bags Count. Then, display the resulting DataFrame. (point: 10)

# %%
data18 = data17.melt(id_vars = 'Date', var_name='Bags', value_name='Count')
data18
# Out:
#           Date        Bags     Count
# 0   2015-12-27  Total Bags   8696.87
# 1   2015-12-20  Total Bags   9505.56
# 2   2015-12-13  Total Bags   8145.35
# 3   2015-12-06  Total Bags   5811.16
# 4   2015-11-29  Total Bags   6183.95
# ..         ...         ...       ...
# 99  2015-02-01  Small Bags   9170.82
# 100 2015-01-25  Small Bags  10103.35
# 101 2015-01-18  Small Bags  11651.09
# 102 2015-01-11  Small Bags   8036.04
# 103 2015-01-04  Small Bags   9186.93
#
# [104 rows x 3 columns]

# %% [markdown]
# #### 19) Plot the melted data with Seaborn in a line plot, using the hue parameter to distinguish between the bag types. (point: 5)

# %%
sns.lineplot(x='Date', y='Count', hue='Bags', palette=['green', 'purple'],data = data18)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %% [markdown]
# #### 20) Bin the data in the Total Volume column into four quantiles labeled ‘poor’, ‘modest’, ‘good’, and ‘excellent’, and store the bin labels in a new column. (point: 10)

# %%
label20 = ['poor', 'modest', 'good', 'excellent']
avocado['total Bin']= pd.qcut(avocado['Total Volume'], q=4, labels = label20)
avocado
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# #### 21) Plot the binned data by year using a Seaborn count plot. (point: 3)

# %%
sns.countplot(x='year', hue = 'total Bin', data = avocado)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %% [markdown]
# #### 22) Of the three bag sizes, which size sells the most? Hint: Melt the three bag size columns and plot the bags by year. (point: 10)

# %%
q22 = pd.melt(avocado_dt, id_vars ='year', value_vars=['Small Bags', 'Large Bags', 'XLarge Bags'], var_name= 'Bags', value_name ='max')
sns.lineplot(x='year', y='max', hue='Bags', data = q22)
# Out:
# <AxesSubplot:xlabel='year', ylabel='max'>

# %% [markdown]
# #### 23) Which type of avocado sells the most? (point: 2)

# %%
avocado.groupby('type')['Total Volume'].sum()
# Out:
# type
# conventional    9.385999e+09
# organic         2.726631e+08
# Name: Total Volume, dtype: float64
